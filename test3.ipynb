# %%
tawiil = {
    "name": {
        "arabic": u"طويل",
        "english": "long",
        "trans": u"tawiil"
    },
    "meter": [[
        
         ("WWSWS",["SALIM", "QABDH"]),
         ("WWSWSWS",["SALIM", "QABDH", "KAFF"]),
         ("WWSWS",["SALIM", "QABDH"]),
         ("WWSWSWS",["QABDH"]),
        
    ]],
    "key": u"طويلٌ له دون البحور فضائلٌ  فعولن مفاعيلن فعولن مفاعلن"
}

madiid = {
    "name": {
        "arabic": u"مديد",
        "english": "protracted",
        "trans": u"madiid"
    },
    "meter": [[
        
         ("WSWWSWS",["SALIM", "KHABN"]),
         ("WSWWS",["SALIM", "KHABN"]),
         ("WSWWSWS",["SALIM", "KHABN"])
        
    ]],
    "key": u"لمديد الشعر عندي صفاتُ  فاعلاتن فاعلن فاعلاتن"
}

basiit = {
    "name": {
        "arabic": u"بسيط",
        "english": "spread-out",
        "trans": u"basiit"
    },
    "meter": [[
        
         ("WSWSWWS",["SALIM", "KHABN", "TAI"]),
         ("WSWWS",["SALIM", "KHABN"]),
         ("WSWSWWS",["SALIM", "KHABN", "TAI"]),
         ("WSWWS",["KHABN", "QATE"]),
        ],
        [
         ("WSWSWWS",["SALIM", "KHABN", "TAI"]),
         ("WSWWS",["SALIM", "KHABN"]),
         ("WSWSWWS",["SALIM", "KHABN", "TAI", "QATE", "TADIIL"]),
        
    ]],
    "key": u"إن البسيط لديه يبسط الأملُ  مستفعلن فعلن مستفعلن فعلن"
}

wafir = {
    "name": {
        "arabic": u"وافر",
        "english": "abundant",
        "trans": u"wafir"
    },
    "meter": [[
        
         ("WWSWWWS",["SALIM", "ASAB"]),
         ("WWSWWWS",["SALIM", "ASAB"]),
         ("WWSWS",["SALIM"]),
        
    ]],
    "key": u"بحور الشعر وافرها جميل  مفاعلتن مفاعلتن فعولن"
}

kaamil = {
    "name": {
        "arabic": u"كامل",
        "english": "complete",
        "trans": u"kaamil"
    },
    "meter": [[
        
         ("WWWSWWS",["SALIM", "IDHMAR"]),
         ("WWWSWWS",["SALIM", "IDHMAR"]),
         ("WWWSWWS",["SALIM", "IDHMAR"])
        ],
        [
         ("WWWSWWS",["SALIM", "IDHMAR"]),
         ("WWWSWWS",["SALIM", "IDHMAR"])
        
    ]],
    "key": u"كمل الجمال من البحور الكامل متفاعلن متفاعلن متفاعلن"
}

hazj = {
    "name": {
        "arabic": u"هزج",
        "english": "trilling",
        "trans": u"hazj",
    },
    "meter": [[
        
         ("WWSWSWS",["SALIM", "KAFF"]),
         ("WWSWSWS",["SALIM", "KAFF"])
        
    ]],
    "key": u"على الأهزاج تسهيل      مفاعيلن مفاعيلن"
}

rajz = {
    "name": {
        "arabic": u"رجز",
        "english": "trembling",
        "trans": u"rajz"
    },
    "meter": [[
        
         ("WSWSWWS",["SALIM", "KHABN"]),
         ("WSWSWWS",["SALIM", "KHABN"]),
         ("WSWSWWS",["SALIM", "KHABN"])
        
    ]],
    "key": u"في أبحر الأرجاز بحرٌ يسهل   مستفعلن مستفعلن مستفعلن"
}

raml = {
    "name": {
        "arabic": u"رمل",
        "english": "trotting",
        "trans": u"raml",
    },
    "meter": [[
        
         ("WSWWSWS",["SALIM", "KHABN"]),
         ("WSWWSWS",["SALIM", "KHABN"]),
         ("WSWWSWS",["SALIM", "KHABN"])
        
    ]],
    "key": u"رمل الأبحر ترويه الثقات فاعلاتن فاعلاتن فاعلاتن"
}

sariie = {
    "name": {
        "arabic": u"سريع",
        "english": "swift",
        "trans": u"sariie",
    },
    "meter": [[
        
         ("WSWSWWS",["SALIM", "KHABN", "TAI", "KHABL"]),
         ("WSWSWWS",["SALIM", "KHABN", "TAI", "KHABL"]),
         ("WSWWS",["SALIM"])
        
    ]],
    "key": u"بحرٌ سريع ماله ساحل مستفعلن مستفعلن فاعلن"
}

munsarih = {
    "name": {
        "arabic": u"منسرح",
        "english": "quick-paced",
        "trans": u"munsarih"
    },
    "meter": [[
        
         ("WSWSWWS",["SALIM", "KHABN"]),
         ("WSWSWSW",["SALIM", "TAI"]),
         ("WSWSWWS",["TAI"])
        
    ]],
    "key": u"منسرح فيه يضرب المثل    مستفعلن مفعولات مفتعلن"
}

khafiif = {
    "name": {
        "arabic": u"خفيف",
        "english": "light",
        "trans": u"khafiif"
    },
    "meter": [[
        
         ("WSWWSWS",["SALIM", "KHABN", "KAFF"]),
         ("WSWSWWS",["SALIM"]),
         ("WSWWSWS",["SALIM", "KHABN", "SHAKL"])
        
    ]],
    "key": u"يا خفيفاً خفّت به الحركات   فاعلاتن مستفعلن فاعلاتن"
}


mujdath = {
    "name": {
        "arabic": u"مجتث",
        "english": "cut-off",
        "trans": u"mujdath"
    },
    "meter": [[
        
         ("WSWSWWS",["SALIM", "KHABN"]),
         ("WSWWSWS",["SALIM", "KHABN"])
        
    ]],
    "key": u"أن جثت الحركات  مستفعلن فاعلاتن"
}

mutaqaarib = {
    "name": {
        "arabic": u"متقارب",
        "english": "nearing",
        "trans": u"mutaqaarib"
    },
    "meter": [[
        
         ("WWSWS",["SALIM", "QABDH"]),
         ("WWSWS",["SALIM", "QABDH"]),
         ("WWSWS",["SALIM", "QABDH"]),
         ("WWSWS",["SALIM", "QABDH", "QASR"])
        
    ]],
    "key": u"عن المتقارب قال الخليل      فعولن فعولن فعولن فعول"
}


mutadaarik = {
    "name": {
        "arabic": u"متدارك",
        "english": "overtaking",
        "trans": u"mutadaarik"
    },
    "meter": [[
        
         ("WSWWS",["SALIM", "KHABN", "QATE"]),
         ("WSWWS",["SALIM", "KHABN", "QATE"]),
         ("WSWWS",["SALIM", "KHABN", "QATE"]),
         ("WSWWS",["SALIM", "KHABN", "QATE"])
        
    ]],
    "key": u"حركات المحدث تنتقل  فعلن فعلن فعلن فعل"
}

bohor = [tawiil,
madiid,
basiit,
wafir,
kaamil,
hazj,
rajz,
raml,
sariie,
munsarih,
khafiif,
mujdath,
mutaqaarib,
mutadaarik]

# %%
WSWWS = {
    "SALIM": u"فَاعِلُنْ",
    "KHABN": u"فَعِلُنْ",
    "TARFIIL": u"فَاعِلَاتُنْ",
    "TADIIL": u"فَاعِلَانْ",
    "QATE": u"فِعْلُنْ",
}

WWSWS = {
    "SALIM": u"فَعُولُنْ",
    "QABDH": u"فَعُولُ",
    "HADF": u"فِعَلْ",
    "BATR": u"فِعْ",
    "QASR": u"فَعُولْ",
}

WWSWSWS = {
    "SALIM": u"مَفَاعِيلُنْ",
    "QABDH": u"مَفَاعِلُنْ",
    "KAFF": u"مَفَاعِيلُ",
    "HADF": u"فَعُولُنْ",
}

WSWSWWS = {
    "SALIM": u"مُسْتَفْعِلُنْ",
    "KHABN": u"مُتَفْعِلُنْ",
    "TAI": u"مُسْتَعِلُنْ",
    "KHABL": u"مُتَعِلُنْ",
    "TADIIL": u"مُسْتَفْعِلَانْ",
    "QATE": u"مَفْعُولُنْ",
}

WWWSWWS = {
    "SALIM": u"مُتَفَاعِلُنْ",
    "IDHMAR": u"مُتْفَاعِلُنْ",
    "WAQS": u"مُفَاعِلُنْ",
    "KHAZL": u"مُتْفَعِلُنْ",
    "TARFIIL": u"مُتَفَاعِلَاتُنْ",
    "TADIIL": u"مُتَفَاعِلَانْ",
    "QATE": u"مُتَفَاعِلْ",
    "HADAD": u"فِعْلُنْ",
}

WWSWWWS = {
    "SALIM": u"مُفَاعَلَتُنْ",
    "ASAB": u"مُفَاعَلْتُنْ",
    "AQL": u"مُفَاعَتُنْ",
    "NAQS": u"مُفَاعَلْتُ",
    "QATF": u"فَعُولُنْ",
}

WSWWSWS = {
    "SALIM": u"فَاعِلَاتُنْ",
    "KHABN": u"فَعِلَاتُنْ",
    "KAFF": u"فَاعِلَاتُ",
    "ISBAGH": u"فَاعِلَاتَانْ",
    "HADF": u"فَاعِلُنْ",
    "SHAKL": u"فَعِلَاتُ",
    "BATR": u"فِعْلُنْ",
    "QASR": u"فَاعِلَانْ",
}

WSWSWSW = {
    "SALIM": u"مَفْعُولَاتُ",
    "KHABN": u"مَعُولَاتُ",
    "TAI": u"مَفْعُلَاتُ",
    "KHABL": u"مَعُلَاتُ",
    "SALAM": u"فِعْلُنْ",
    "KASHF": u"مَفْعُولُنْ",
}

zuhaf_dict = {
    'WSWWS':WSWWS,
    'WWSWS':WWSWS,
    'WWSWSWS':WWSWSWS,
    'WSWSWWS':WSWSWWS,
    'WWWSWWS':WWWSWWS,
    'WWSWWWS':WWSWWWS,
    'WSWWSWS':WSWWSWS,
    'WSWSWSW':WSWSWSW,
}

# %%
def solve(tafilat, n, s):

    if n == len(tafilat):
        res.append(' '.join(s))

    else:
        tafila = tafilat[n][0]
        for mode in tafilat[n][1]:
            s.append(zuhaf_dict[tafila][mode])
            solve(tafilat, n+1, s)
            s.pop()

# %%
meter['name']['trans']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7761/123748654.py in <module>
# ----> 1 meter['name']['trans']
#
# NameError: name 'meter' is not defined

# %%
res2 = []
for meter in bohor:
    for tafilat in meter['meter']:
        res = []
        solve(tafilat, 0, [])
        res2.append((meter['name']['trans'], res.copy()))

# %%
res2
# Out:
# [('tawiil',
#   ['فَعُولُنْ مَفَاعِيلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِيلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِيلُ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِيلُ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُ فَعُولُ مَفَاعِلُنْ']),
#  ('madiid',
#   ['فَاعِلَاتُنْ فَاعِلُنْ فَاعِلَاتُنْ',
#    'فَاعِلَاتُنْ فَاعِلُنْ فَعِلَاتُنْ',
#    'فَاعِلَاتُنْ فَعِلُنْ فَاعِلَاتُنْ',
#    'فَاعِلَاتُنْ فَعِلُنْ فَعِلَاتُنْ',
#    'فَعِلَاتُنْ فَاعِلُنْ فَاعِلَاتُنْ',
#    'فَعِلَاتُنْ فَاعِلُنْ فَعِلَاتُنْ',
#    'فَعِلَاتُنْ فَعِلُنْ فَاعِلَاتُنْ',
#    'فَعِلَاتُنْ فَعِلُنْ فَعِلَاتُنْ']),
#  ('basiit',
# ...

# %%
res3 = {}
for m in res2:
    if m[0] in res3:
        res3[m[0]].append(m[1])
    else:
        res3[m[0]] = [m[1]]

# %%
res3
# Out:
# {'tawiil': [['فَعُولُنْ مَفَاعِيلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِيلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِيلُ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُنْ مَفَاعِيلُ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِلُنْ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِلُنْ فَعُولُ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُ فَعُولُنْ مَفَاعِلُنْ',
#    'فَعُولُ مَفَاعِيلُ فَعُولُ مَفَاعِلُنْ']],
#  'madiid': [['فَاعِلَاتُنْ فَاعِلُنْ فَاعِلَاتُنْ',
#    'فَاعِلَاتُنْ فَاعِلُنْ فَعِلَاتُنْ',
#    'فَاعِلَاتُنْ فَعِلُنْ فَاعِلَاتُنْ',
#    'فَاعِلَاتُنْ فَعِلُنْ فَعِلَاتُنْ',
#    'فَعِلَاتُنْ فَاعِلُنْ فَاعِلَاتُنْ',
#    'فَعِلَاتُنْ فَاعِلُنْ فَعِلَاتُنْ',
#    'فَعِلَاتُنْ فَعِلُنْ فَاعِلَاتُنْ',
#    'فَعِلَاتُنْ فَعِلُنْ فَعِلَاتُنْ']],
# ...

# %%
2 * 3 * 2 * 1
# Out:
# 12

# %%
tawiil = {
    "name": {
        "arabic": u"طويل",
        "english": "long",
        "trans": u"ṭawīl"
    },
    "meter": [[
        
         ("WWSWS",["SALIM", "QABDH"]),
         ("WWSWSWS",["SALIM", "QABDH", "KAFF"]),
         ("WWSWS",["SALIM", "QABDH"]),
         ("WWSWSWS",["QABDH"]),
        
    ]],
    "key": u"طويلٌ له دون البحور فضائلٌ  فعولن مفاعيلن فعولن مفاعلن"
}

# %%
tawiil["meter"][0][2]
# Out:
# ('WWSWS', ['SALIM', 'QABDH'])

# %%
zuhaf_dict['WWSWS']['SALIM']
# Out:
# 'فَعُولُنْ'

# %%
20 ----- 100
x ------ 1684668

# %%
(100000 * 20) / 100
# Out:
# 20000.0

# %%
20000 / 3600
# Out:
# 5.555555555555555
